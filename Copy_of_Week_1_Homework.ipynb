# %% [markdown]
# <a href="https://colab.research.google.com/github/artlessmonarch-boop/Week4Warmup/blob/main/Copy_of_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://ahva-ubc.github.io/Heaven-and-Earth/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "January, from the Les Tr\u00e8s Riches Heures du Duc de Berry",
#   "creator": "Limbourg Brothers (fl. 1385-1416)",
#   "date": "1385-1416",
#   "description": "The Duke of Berry, seated lower right, with his back to the fire, is dressed in blue and wearing a fur cap. He invites his people and relatives to introduce themselves to him. Behind him is the inscription \u201cApproche Approche\u201d. Several of the duke's familiars approach him while servants are busy: the cupbearers are serving drinks, two sharp squires in the center are seen from behind; at the end of the table officiates a baker. Above the fireplace are the duke's coat of arms, \"azure strewn with fleur-de-lis d'or, with a engrailed border gules\", with small bears and wounded swans. Several pets are represented: small dogs on the table, greyhound on the ground. The tapestry\nat the back of the room seems to represent episodes from the Trojan War",
#   "location": "Chantilly, France",
#   "latitude": "49.19551862",
#   "longitude": "2.494349077",
#   "format": "image/jpeg",
#   "rights": "\"January, from the Les Tr\u00e8s Riches Heures du Duc de Berry\" by: R-G Oj\u00e9da/RMN (https://commons.wikimedia.org/wiki/File:Les_Tr%C3%A8s_Riches_Heures_du_duc_de_Berry_Janvier.jpg), PD-US",
#   "reference_url": "https://ahva-ubc.github.io/Heaven-and-Earth/item.html?id=image3"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://ahva-ubc.github.io/Heaven-and-Earth/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {}
#     },
#     {
#       "field": "creator",
#       "terms": {
#         "aertsen, pieter (1508-1575)": 1,
#         "altdorfer, albrecht (1480-1538)": 2,
#         "anonymous": 1,
#         "anonymous bavarian artist": 1,
#         "baldung, hans (1484/85-1545)": 4,
#         "bosch, hieronymous (1450-1516)": 2,
#         "bruegel, peter (c. 1525/30-1569)": 2,
#         "campin, robert (c. 1375-1444)": 1,
#         "cranach, lucas (c. 1472-1553)": 1,
#         "d\u00fcrer, albrecht (1471-1528)": 5,
#         "gr\u00fcnewald, matthias (1470-1528)": 2,
#         "hans memling (1433-1494)": 1,
#         "holbein, hans (c. 1497-1543)": 3,
#         "limbourg brothers (fl. 1385-1416)": 2,
#         "massy, quentin (1466-1530)": 1,
#         "master e.s. (german, active ca. 1450\u201367)": 1,
#         "riemenschneider, tilman (1460-1531)": 1,
#         "schongauer, martin (1435/50-1491)": 1,
#         "sluter, claus (1340-1406)": 1,
#         "van der goes, hugo (1430/40-1482)": 1,
#         "van der weyden, rogier (1399-1464)": 1,
#         "van eyck, jan (1390-1441)": 2
#       }
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 35,
#         "image/png": 2
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - facet 1: subject
# - facet 2: creator
# - facet 3: format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# Facets creator and format show up an equal number of times at 37.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                 title  \
# 0   January, from the Les Très Riches Heures du Du...
# 1   February, from the Les Très Riches Heures du D...
# 2                                          King David
# 3                               Madonna of Chancellor
# 4      Portrait of Giovanni(?) Arnolfini and his Wife
# 5    Merode altarpiece (Triptych of the Annunciation)
# 6             Deposition (aka Descent from the Cross)
# 7                                Portinari altarpiece
# 8                          Marten Nieuwenhove diptych
# 9                          Garden of Earthly Delights
# 10                                St Anthony Triptych
# 11                            Altar of the Holy Blood
# 12                        Isenheim Altarpiece (front)
# 13                         Isenheim Altarpiece (back)
# 14  Virgin and Child in glory w/ Sts Catherine and...
# 15                                        St. Dorothy
# 16                                     Man of Sorrows
# 17                                  Christ the Savior
# 18                            John Devouring the Book
# 19                    Four horseman of the Apocalypse
# 20              Self-Portrait in Fur Coat (as Christ)
# 21                                Portrait of Erasmus
# 22                                  The Four Holy Men
# 23                 Allegory of the Law and the Gospel
# 24                          St. George and the Dragon
# 25                                       Satyr family
# 26                        Eve, the Serpent, and Death
# 27                               Death and the maiden
# 28                               Death and the maiden
# 29                                    Witches Sabbath
# 30                             Hermann von Wedigh III
# 31                                        Derich Born
# 32                                    The Ambassadors
# 33                                 Ill Matched Lovers
# 34  Butcher’s Stall (A Meat Stall with the Holy Fa...
# 7   "Portinari altarpiece" by the Yorck Project (2...
# 8   "Marten Nieuwenhove diptych" by the Web Galler...
# 9   "Garden of Earthly Delights" by the Bosch Proj...
# 10  "St. Anthony Triptych" by Paul Hermans (19 Oct...
# 11  "Altar of the Holy Blood" by Holger Uwe Schmit...
# 12  "Isenheim Altarpiece (first view)" by Archaeod...
# 13  "Isenheim Altarpiece (second view)" by Archaeo...
# 14  "The Virgin and Child in glory, with St Cather...
# 15  Anonymous, Saint Dorothy and the Christ Child....
# 16  "Man of Sorrows" by Metropolitan Museum, Harri...
# 17  "Christ the Savior" by the Metropolitan Museum...
# 18  "John Devouring the Book" by the Royal Collect...
# 19  "Four horseman of the Apocalypse" by the Metro...
# 20  "Self-Portrait in Fur Coat (as Christ)" by the...
# 21  "Portrait of Erasmus" by the Metropolitan Muse...
# 22  "The Four Holy Men", : by Immanuel Giel, (http...
# 23  "Allegory of the Law and the Gospel", by the B...
# 24  "St. George and the Dragon", by the Yorck Proj...
# 25  "Satyr family" by Sailko, (https://commons.wik...
# 26  "Eve, the Serpent, and Death" by the Musée des...
# 27  "Death and the maiden", by the Web Gallery of ...
# 28  "Death and the maiden", by The Yorck Project (...
# 29  "Witches Sabbath" by the Metropolitan Museum, ...
# 30  "Hermann von Wedigh III" by the Metropolitan M...
# 31  "Derich Born" by the Royal Trust Collection, (...
# 32  The Ambassadors, by the National Gallery of Ar...
# 33  "Ill Matched Lovers" by the National Gallery o...
# 34  Credit: https://en.wikipedia.org/wiki/File:A_M...
# 35  Kermis" by the Web Gallery of Art, Emil Krén a...
# 36  "Wheat Harvest" by the Metropolitan Museum, Ro...
#
#                                         reference_url
# 0   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 1   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 2   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 3   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 4   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 5   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 6   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 7   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 8   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 9   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 10  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 11  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 12  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 13  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 14  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 15  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 16  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 17  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 18  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 19  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 20  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 21  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 22  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 23  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 24  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 25  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 26  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 27  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 28  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 29  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 30  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 31  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 32  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 33  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 34  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 35  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 36  https://ahva-ubc.github.io/Heaven-and-Earth/it...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                                                 title  \
# 19                    Four horseman of the Apocalypse
# 11                            Altar of the Holy Blood
# 9                          Garden of Earthly Delights
# 26                        Eve, the Serpent, and Death
# 10                                St Anthony Triptych
# 34  Butcher’s Stall (A Meat Stall with the Holy Fa...
# 27                               Death and the maiden
# 35                                             Kermis
# 0   January, from the Les Très Riches Heures du Du...
# 22                                  The Four Holy Men
#
#                                 creator       date  \
# 19          Dürer, Albrecht (1471-1528)       1497
# 11  Riemenschneider, Tilman (1460-1531)  1499-1505
# 9        Bosch, Hieronymous (1450-1516)  1510-1515
# 26         Baldung, Hans (1484/85-1545)       1520
# 10       Bosch, Hieronymous (1450-1516)  1505-1510
# 34          Aertsen, Pieter (1508-1575)       1551
# 27         Baldung, Hans (1484/85-1545)       1518
# 35     Bruegel, Peter (c. 1525/30-1569)       1568
# 0     Limbourg Brothers (fl. 1385-1416)  1385-1416
# 22          Dürer, Albrecht (1471-1528)       1526
#
#                                           description  \
# 19  The third and most famous woodcut from Dürer's...
# 11                                                NaN
# 9   The Garden of Earthly Delights is Bosch’s most...
# 26  In this panel, the bodies are grand in scale a...
# 10  The work tells symbolically the story of the m...
# 34  The artwork of A Meat Stall with the Holy Fami...
# 27  In this painting a voluptuous young maiden tur...
# 35  The panel, neither signed nor dated, was paint...
# 0   The Duke of Berry, seated lower right, with hi...
# 22  The Four Apostles is a panel painting by the G...
#
#                              location     latitude     longitude      format  \
# 19                      New York, USA  40.77965593  -73.96264319  image/jpeg
# 11  Rothenburg ob der Tauber, Germany  49.38089844   10.18001824  image/jpeg
# 9                       Madrid, Spain  40.41401867  -3.691665762  image/jpeg
# 26                     Ottawa, Canada  45.42973074  -75.69846632  image/jpeg
# 10                   Lisbon, Portugal  38.70508398  -9.160783021  image/jpeg
# 34                       Raleigh, USA   35.8101206  -78.70200977  image/jpeg
# 27                 Basel, Switzerland  47.55943989   7.588792254  image/jpeg
# 35                    Vienna, Austria   48.2040161   16.36238821  image/jpeg
# 0                   Chantilly, France  49.19551862   2.494349077  image/jpeg
# 22                    Munich, Germany  48.13541752   11.57994325  image/jpeg
#
#                                                rights  \
# 19  "Four horseman of the Apocalypse" by the Metro...
# 11  "Altar of the Holy Blood" by Holger Uwe Schmit...
# 9   "Garden of Earthly Delights" by the Bosch Proj...
# 26  "Eve, the Serpent, and Death" by the Musée des...
# 10  "St. Anthony Triptych" by Paul Hermans (19 Oct...
# 34  Credit: https://en.wikipedia.org/wiki/File:A_M...
# 27  "Death and the maiden", by the Web Gallery of ...
# 35  Kermis" by the Web Gallery of Art, Emil Krén a...
# 0   "January, from the Les Très Riches Heures du D...
# 22  "The Four Holy Men", : by Immanuel Giel, (http...
#
#                                         reference_url
# 19  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 11  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 9   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 26  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 10  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 34  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 27  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 35  https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 0   https://ahva-ubc.github.io/Heaven-and-Earth/it...
# 22  https://ahva-ubc.github.io/Heaven-and-Earth/it...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized["creator"].value_counts()
# Out:
# creator
# Dürer, Albrecht (1471-1528)                 5
# Baldung, Hans (1484/85-1545)                4
# Holbein, Hans (c. 1497-1543)                3
# Bosch, Hieronymous (1450-1516)              2
# Limbourg Brothers (fl. 1385-1416)           2
# van Eyck, Jan (1390-1441)                   2
# Altdorfer, Albrecht (1480-1538)             2
# Grünewald, Matthias (1470-1528)             2
# Bruegel, Peter (c. 1525/30-1569)            2
# Sluter, Claus (1340-1406)                   1
# van der Goes, Hugo (1430/40-1482)           1
# van der Weyden, Rogier (1399-1464)          1
# Campin, Robert (c. 1375-1444)               1
# Hans Memling (1433-1494)                    1
# Master E.S. (German, active ca. 1450–67)    1
# Schongauer, Martin (1435/50-1491)           1
# Anonymous Bavarian artist                   1
# Anonymous                                   1
# Riemenschneider, Tilman (1460-1531)         1
# Cranach, Lucas (c. 1472-1553)               1
# Massy, Quentin (1466-1530)                  1
# Aertsen, Pieter (1508-1575)                 1
# Name: count, dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
